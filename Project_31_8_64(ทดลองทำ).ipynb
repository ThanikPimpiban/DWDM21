# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanikPimpiban/DWDM21/blob/main/Project_31_8_64(%E0%B8%97%E0%B8%94%E0%B8%A5%E0%B8%AD%E0%B8%87%E0%B8%97%E0%B8%B3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #ส่วนของการ Import
import os

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/DWDM_Project' #กำหนด path ของโฟลเดอร์ที่ Data อยู่

# %%
data_st = pd.read_csv(os.path.join(path,'data_station.csv')) #กำหนดตัวแปร data_st เป็นข้อมูลของสถานีรถไฟแต่ละสถานี
data_st #เรียกดูตารางของสถานีรถไฟแต่ละสถานี
# Out:
#       id  station_code           name  ... giveway dual_track          comment
# 0      1          1001        กรุงเทพ  ...       1          1              NaN
# 1      2          1002          ยมราช  ...       1          1              NaN
# 2      3          1004         สามเสน  ...       1          1              NaN
# 3      4          1006     ประดิพัทธ์  ...       1          1          ป.สระอิ
# 4      5          1007  ชุมทางบางซื่อ  ...       1          1              NaN
# ..   ...           ...            ...  ...     ...        ...              ...
# 677  678          5025       บางโทรัด  ...       0          0  ศก.สน. กม.13.82
# 678  679          5026      บ้านกาหลง  ...       0          0  ศก.สน. กม.15.78
# 679  680          5027     บ้านนาขวาง  ...       0          0  ศก.สน. กม.17.94
# 680  681          5028      บ้านนาโคก  ...       0          0  ศก.สน. กม.19.97
# 681  682          5029       เขตเมือง  ...       0          0  ศก.สน. กม.23.73
#
# [682 rows x 18 columns]

# %%
data_t = pd.read_csv(os.path.join(path,'data_train.csv')) #กำหนดตัวแปร data_t เป็นข้อมูลของรถไฟ
data_t #เรียกดูตาราง
# Out:
#      Zone  goback   Num  ...            NameStEng            NameStEng_L  Service
# 0       1       1   0.0  ...              Bangkok       Ban Plu Ta Luang    False
# 1       1       1   1.0  ...              Bangkok      Bang Sue Junction     True
# 2       1       1   1.0  ...             Makkasan              Hua Takhe    False
# 3       1       1   2.0  ...              Bangkok      Bang Sue Junction     True
# 4       1       1   4.0  ...              Bangkok       Ban Plu Ta Luang    False
# ..    ...     ...   ...  ...                  ...                    ...      ...
# 229     5       2  26.0  ...              Nam Tok              Thon Buri    False
# 230     5       2  27.0  ...  Prachuap Khiri Khan              Thon Buri    False
# 231     5       2  28.0  ...            Lang Suan              Thon Buri    False
# 232     5       2  29.0  ...              Nam Tok              Thon Buri    False
# ...

# %%
data_rst = pd.read_csv(os.path.join(path,'railstation_new.csv')) #กำหนดตัวแปร data_rst ให้เป็นรางรถไฟ
data_rst #เรียกดูตารางของรางรถไฟ
# Out:
#      OBJECTID                      NAMET  ... Unnamed: 10 Unnamed: 11
# 0           1               บ้านเกาะปริง  ...         NaN         NaN
# 1           2                    ห้วยยอด  ...         NaN         NaN
# 2           3            โรงเรียนการบิน   ...         NaN         NaN
# 3           4                บ้านปลักแรด  ...         NaN         NaN
# 4           5                    เด่นชัย  ...         NaN         NaN
# ..        ...                        ...  ...         ...         ...
# 677       678  ศูนย์ราชการจังหวัดสระแก้ว  ...         NaN         NaN
# 678       679                    ทุ่งทอง  ...         NaN         NaN
# 679       680                ตลาดหนองคาย  ...         NaN         NaN
# 680       681               แกรนด์ คาแนล  ...         NaN         NaN
# 681       682                   หัวลำโพง  ...         NaN         NaN
#
# [682 rows x 12 columns]

# %%
merged_data_t_data_st = data_st.merge(data_t,how='right',left_on='station_code',right_on='StFinal') #ทำการเชื่อมตาราง 2 ตาราง คือ 1.ข้อมูลของรางรถไฟ 2.ข้อมูลของสถานีรถไฟแต่ละสถานี
merged_data_t_data_st #เรียกตารางที่เชื่อมกัน 2 ตารางข้างต้น
# Out:
#       id  station_code  ...            NameStEng_L Service
# 0    331          3047  ...       Ban Plu Ta Luang   False
# 1    331          3047  ...       Ban Plu Ta Luang   False
# 2      5          1007  ...      Bang Sue Junction    True
# 3      5          1007  ...      Bang Sue Junction    True
# 4    307          3015  ...              Hua Takhe   False
# ..   ...           ...  ...                    ...     ...
# 229  442          4089  ...              Rachaburi   False
# 230  535          4238  ...     Khiri Ratthanikhom   False
# 231  501          4186  ...               Chumphon   False
# 232  595          4325  ...            Phatthalung   False
# 233  394          4020  ...  Nong Pla Duk Junction   False
#
# [234 rows x 30 columns]

# %%
merged_3_tables =merged_data_t_data_st.merge(data_location,how='left',left_on='NameSt',right_on='แขวง/ตำบล') #ทำเชื่อมตารางระหว่าง 1.ตารางของรางรถไฟและตารางสถานีรถไฟแต่ละสถานี 2.ตารางรถไฟ
merged_3_tables #เรียกดูตารางที่เชื่อมกันทั้ง 3 ตาราง
# Out:
#       id  station_code              name  ...   แขวง/ตำบล รหัสไปรษณีย์ หมายเหตุ
# 0    331          3047     บ้านพลูตาหลวง  ...         NaN          NaN      NaN
# 1    331          3047     บ้านพลูตาหลวง  ...         NaN          NaN      NaN
# 2      5          1007     ชุมทางบางซื่อ  ...         NaN          NaN      NaN
# 3      5          1007     ชุมทางบางซื่อ  ...         NaN          NaN      NaN
# 4    307          3015          หัวตะเข้  ...    มักกะสัน      10400.0      NaN
# ..   ...           ...               ...  ...         ...          ...      ...
# 233  535          4238       คีรีรัฐนิคม  ...         NaN          NaN      NaN
# 234  501          4186             ชุมพร  ...         NaN          NaN      NaN
# 235  595          4325            พัทลุง  ...  สุไหงโก-ลก      96120.0      NaN
# 236  394          4020  ชุมทางหนองปลาดุก  ...       น้ำตก      55150.0      NaN
# 237  394          4020  ชุมทางหนองปลาดุก  ...       น้ำตก      80110.0      NaN
#
# ...

# %%
merged_3_tables_new =merged_3_tables.merge(data_location,how='left',left_on='NameSt',right_on='จังหวัด') #ทำเชื่อมตารางระหว่าง 1.ตารางของรางรถไฟและตารางสถานีรถไฟแต่ละสถานี 2.ตารางรถไฟ
merged_3_tables_new #เรียกดูตารางที่เชื่อมกันทั้ง 3 ตาราง
# Out:
#         id  station_code  ... รหัสไปรษณีย์_y หมายเหตุ_y
# 0      331          3047  ...        10200.0        NaN
# 1      331          3047  ...        10200.0        NaN
# 2      331          3047  ...        10200.0        NaN
# 3      331          3047  ...        10200.0        NaN
# 4      331          3047  ...        10200.0        NaN
# ...    ...           ...  ...            ...        ...
# 24408  535          4238  ...        84180.0        NaN
# 24409  501          4186  ...            NaN        NaN
# 24410  595          4325  ...            NaN        NaN
# 24411  394          4020  ...            NaN        NaN
# 24412  394          4020  ...            NaN        NaN
#
# [24413 rows x 42 columns]

# %%
data_location
# Out:
#       Location Code   จังหวัด  ... รหัสไปรษณีย์ หมายเหตุ
# 0            100101   กรุงเทพ  ...        10200      NaN
# 1            100102   กรุงเทพ  ...        10200      NaN
# 2            100103   กรุงเทพ  ...        10200      NaN
# 3            100104   กรุงเทพ  ...        10200      NaN
# 4            100105   กรุงเทพ  ...        10200      NaN
# ...             ...       ...  ...          ...      ...
# 7421         961203  นราธิวาส  ...        96220      NaN
# 7422         961204  นราธิวาส  ...        96220      NaN
# 7423         961301  นราธิวาส  ...        96130      NaN
# 7424         961302  นราธิวาส  ...        96130      NaN
# 7425         961303  นราธิวาส  ...        96130      NaN
#
# [7426 rows x 6 columns]

# %%
#merged_3_tables =merged_data_rst_data_st.merge(data_rst,how='right',left_on='name',right_on='NAMET') #ทำเชื่อมตารางระหว่าง 1.ตารางของรางรถไฟและตารางสถานีรถไฟแต่ละสถานี 2.ตารางรถไฟ
#merged_3_tables #เรียกดูตารางที่เชื่อมกันทั้ง 3 ตาราง
# Out:
#         id  station_code         name  ... Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0      NaN           NaN          NaN  ...        NaN         NaN         NaN
# 1      NaN           NaN          NaN  ...        NaN         NaN         NaN
# 2      NaN           NaN          NaN  ...        NaN         NaN         NaN
# 3      NaN           NaN          NaN  ...        NaN         NaN         NaN
# 4    102.0        1164.0      เด่นชัย  ...        NaN         NaN         NaN
# ..     ...           ...          ...  ...        ...         ...         ...
# 775    NaN           NaN          NaN  ...        NaN         NaN         NaN
# 776    NaN           NaN          NaN  ...        NaN         NaN         NaN
# 777  297.0        2305.0  ตลาดหนองคาย  ...        NaN         NaN         NaN
# 778    NaN           NaN          NaN  ...        NaN         NaN         NaN
# 779    NaN           NaN          NaN  ...        NaN         NaN         NaN
#
# [780 rows x 42 columns]

# %%
merged_3_tables.isnull().any() #เช็คดู missing ของตารางที่เชื่อมกันทั้ง 3 ตาราง
# Out:
# id                  True
# station_code        True
# name                True
# en_name             True
# th_short            True
# en_short            True
# chname              True
# controldivision     True
# exact_km            True
# exact_distance      True
# km                  True
# class               True
# lat                 True
# long                True
# active              True
# giveway             True
# dual_track          True
# comment             True
# Zone                True
# goback              True
# Num                 True
# IdTrain             True
# NameFee             True
# StStart             True
# NameSt              True
# StFinal             True
# NameSt_L            True
# NameStEng           True
# NameStEng_L         True
# Service             True
# OBJECTID           False
# NAMET              False
# NAMEE              False
# ProvName           False
# AmpName            False
# TamName            False
# X                  False
# ...

# %% [markdown]
# **กำจัดค่า Missing**

# %%
# หา mode
merged_3_tables_Nomissing =merged_3_tables[['NAMET']].mode()
# เติม mode ลงไปแทนค่า missing
merged_3_tables[['NAMET']] = merged_3_tables[['NAMET']].fillna('NAMET')

# %%
merged_3_tables.isnull().any() #เช็ดดู missing ของตารางที่เชื่อมกันทั้ง 3 ตาราง อีกรอบ
# Out:
# id                  True
# station_code        True
# name                True
# en_name             True
# th_short            True
# en_short            True
# chname              True
# controldivision     True
# exact_km            True
# exact_distance      True
# km                  True
# class               True
# lat                 True
# long                True
# active              True
# giveway             True
# dual_track          True
# comment             True
# Zone                True
# goback              True
# Num                 True
# IdTrain             True
# NameFee             True
# StStart             True
# NameSt              True
# StFinal             True
# NameSt_L            True
# NameStEng           True
# NameStEng_L         True
# Service             True
# OBJECTID           False
# NAMET              False
# NAMEE              False
# ProvName           False
# AmpName            False
# TamName            False
# X                  False
# ...

# %%
merged_3_tables #เรียกดูตารางเชื่อมกันทั้ง 3 ตาราง ที่ถูกกำจัด missing แล้ว
# Out:
#         id  station_code         name  ... Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0      NaN           NaN          NaN  ...        NaN         NaN         NaN
# 1      NaN           NaN          NaN  ...        NaN         NaN         NaN
# 2      NaN           NaN          NaN  ...        NaN         NaN         NaN
# 3      NaN           NaN          NaN  ...        NaN         NaN         NaN
# 4    102.0        1164.0      เด่นชัย  ...        NaN         NaN         NaN
# ..     ...           ...          ...  ...        ...         ...         ...
# 775    NaN           NaN          NaN  ...        NaN         NaN         NaN
# 776    NaN           NaN          NaN  ...        NaN         NaN         NaN
# 777  297.0        2305.0  ตลาดหนองคาย  ...        NaN         NaN         NaN
# 778    NaN           NaN          NaN  ...        NaN         NaN         NaN
# 779    NaN           NaN          NaN  ...        NaN         NaN         NaN
#
# [780 rows x 42 columns]

# %% [markdown]
# ## ลองวิเคราะห์

# %%
Ex_0 = merged_3_tables[merged_3_tables['class']==1]        ##ดูชื่อสถานีที่มีขั้นบริการ(Class) เป็น 1
Ex_0[['name','class']]
# Out:
#                name  class
# 4           เด่นชัย    1.0
# 5           เด่นชัย    1.0
# 13    ชุมทางแก่งคอย    1.0
# 14    ชุมทางแก่งคอย    1.0
# 15    ชุมทางแก่งคอย    1.0
# ..              ...    ...
# 660  ชุมทางบ้านภาชี    1.0
# 674          นครปฐม    1.0
# 769     ปาดังเบซาร์    1.0
# 770     ปาดังเบซาร์    1.0
# 771     ปาดังเบซาร์    1.0
#
# [120 rows x 2 columns]

# %%
Ex_1 = merged_3_tables.sort_values(by=['NAMET'],ascending=True)  ##ดูรหัสสถานี ชื่อสถานีและหมายเหตุโดยเรียงจากน้อยไปมาก
Ex_1[['station_code','NAMET','comment']]
# Out:
#      station_code          NAMET comment
# 544        3075.0    กบินทร์บุรี     NaN
# 543        3075.0    กบินทร์บุรี     NaN
# 542        3075.0    กบินทร์บุรี     NaN
# 634           NaN    กบินทร์เก่า     NaN
# 549           NaN         กระสัง     NaN
# ..            ...            ...     ...
# 280           NaN  ไฟบ้านพระพุทธ     NaN
# 97            NaN        ไม้แก่น     NaN
# 324           NaN        ไร่อ้อย     NaN
# 397           NaN    ไร่เกล็ดดาว     NaN
# 129           NaN       ไอสะเตีย     NaN
#
# [780 rows x 3 columns]

# %% [markdown]
# ## นำข้อมูลใหม่เข้า

# %%
data_location = pd.read_csv(os.path.join(path,'Location_Postal_Code.csv')) ## นำเข้าข้อมูลชื่อตำบล อำเภอ และจังหวัด
data_location
# Out:
#       Location Code   จังหวัด  ... รหัสไปรษณีย์ หมายเหตุ
# 0            100101   กรุงเทพ  ...        10200      NaN
# 1            100102   กรุงเทพ  ...        10200      NaN
# 2            100103   กรุงเทพ  ...        10200      NaN
# 3            100104   กรุงเทพ  ...        10200      NaN
# 4            100105   กรุงเทพ  ...        10200      NaN
# ...             ...       ...  ...          ...      ...
# 7421         961203  นราธิวาส  ...        96220      NaN
# 7422         961204  นราธิวาส  ...        96220      NaN
# 7423         961301  นราธิวาส  ...        96130      NaN
# 7424         961302  นราธิวาส  ...        96130      NaN
# 7425         961303  นราธิวาส  ...        96130      NaN
#
# [7426 rows x 6 columns]

# %% [markdown]
# **Merged เพิ่ม**

# %%
data_st ##เรียกดูตารางสถานีรถไฟ
# Out:
#       id  station_code           name  ... giveway dual_track          comment
# 0      1          1001        กรุงเทพ  ...       1          1              NaN
# 1      2          1002          ยมราช  ...       1          1              NaN
# 2      3          1004         สามเสน  ...       1          1              NaN
# 3      4          1006     ประดิพัทธ์  ...       1          1          ป.สระอิ
# 4      5          1007  ชุมทางบางซื่อ  ...       1          1              NaN
# ..   ...           ...            ...  ...     ...        ...              ...
# 677  678          5025       บางโทรัด  ...       0          0  ศก.สน. กม.13.82
# 678  679          5026      บ้านกาหลง  ...       0          0  ศก.สน. กม.15.78
# 679  680          5027     บ้านนาขวาง  ...       0          0  ศก.สน. กม.17.94
# 680  681          5028      บ้านนาโคก  ...       0          0  ศก.สน. กม.19.97
# 681  682          5029       เขตเมือง  ...       0          0  ศก.สน. กม.23.73
#
# [682 rows x 18 columns]

# %%
data_t ##เรียกดูตารางรถไฟ
# Out:
#      Zone  goback   Num  ...            NameStEng            NameStEng_L  Service
# 0       1       1   0.0  ...              Bangkok       Ban Plu Ta Luang    False
# 1       1       1   1.0  ...              Bangkok      Bang Sue Junction     True
# 2       1       1   1.0  ...             Makkasan              Hua Takhe    False
# 3       1       1   2.0  ...              Bangkok      Bang Sue Junction     True
# 4       1       1   4.0  ...              Bangkok       Ban Plu Ta Luang    False
# ..    ...     ...   ...  ...                  ...                    ...      ...
# 229     5       2  26.0  ...              Nam Tok              Thon Buri    False
# 230     5       2  27.0  ...  Prachuap Khiri Khan              Thon Buri    False
# 231     5       2  28.0  ...            Lang Suan              Thon Buri    False
# 232     5       2  29.0  ...              Nam Tok              Thon Buri    False
# ...

# %%
data_rst ##เรียกดูตารางรางรถไฟ
# Out:
#      OBJECTID                      NAMET  ... Unnamed: 10 Unnamed: 11
# 0           1               บ้านเกาะปริง  ...         NaN         NaN
# 1           2                    ห้วยยอด  ...         NaN         NaN
# 2           3            โรงเรียนการบิน   ...         NaN         NaN
# 3           4                บ้านปลักแรด  ...         NaN         NaN
# 4           5                    เด่นชัย  ...         NaN         NaN
# ..        ...                        ...  ...         ...         ...
# 677       678  ศูนย์ราชการจังหวัดสระแก้ว  ...         NaN         NaN
# 678       679                    ทุ่งทอง  ...         NaN         NaN
# 679       680                ตลาดหนองคาย  ...         NaN         NaN
# 680       681               แกรนด์ คาแนล  ...         NaN         NaN
# 681       682                   หัวลำโพง  ...         NaN         NaN
#
# [682 rows x 12 columns]

# %%
data_rst.drop(['Unnamed: 9', 'Unnamed: 10','Unnamed: 11'], axis='columns', inplace=True) ## ทำการตัด Column ที่ไม่ได้ใช้ออก ได้แก่ 'Unnamed: 9', 'Unnamed: 10' และ 'Unnamed: 11'
data_rst ##เรียกดูตารางรางรถไฟ
# Out:
#      OBJECTID                      NAMET  ...          Y Neareat_AH
# 0           1               บ้านเกาะปริง  ...   8.213274
# 1           2                    ห้วยยอด  ...   7.785456
# 2           3            โรงเรียนการบิน   ...  14.088246
# 3           4                บ้านปลักแรด  ...  14.530267
# 4           5                    เด่นชัย  ...  17.980781       AH13
# ..        ...                        ...  ...        ...        ...
# 677       678  ศูนย์ราชการจังหวัดสระแก้ว  ...  13.799641
# 678       679                    ทุ่งทอง  ...  13.980168
# 679       680                ตลาดหนองคาย  ...  17.878784
# 680       681               แกรนด์ คาแนล  ...  13.941516
# 681       682                   หัวลำโพง  ...  13.744026        AH2
#
# [682 rows x 9 columns]

# %%
data_location ##เรียกดูตารางที่ตั้ง
# Out:
#       Location Code   จังหวัด  ... รหัสไปรษณีย์ หมายเหตุ
# 0            100101   กรุงเทพ  ...        10200      NaN
# 1            100102   กรุงเทพ  ...        10200      NaN
# 2            100103   กรุงเทพ  ...        10200      NaN
# 3            100104   กรุงเทพ  ...        10200      NaN
# 4            100105   กรุงเทพ  ...        10200      NaN
# ...             ...       ...  ...          ...      ...
# 7421         961203  นราธิวาส  ...        96220      NaN
# 7422         961204  นราธิวาส  ...        96220      NaN
# 7423         961301  นราธิวาส  ...        96130      NaN
# 7424         961302  นราธิวาส  ...        96130      NaN
# 7425         961303  นราธิวาส  ...        96130      NaN
#
# [7426 rows x 6 columns]

# %%
merged_4_tables_new = merged_3_tables.merge(data_location,how='left',left_on='NAMET',right_on='แขวง/ตำบล') ##เชื่อมตารางที่ตั้งเพิ่มเข้าไป ที่เชื่อมด้วยคีย์ NAMET กับ แขวง/ตำบล

# %%
merged_4_tables_new ##เรียกดูตารางใหม่
# Out:
#          id  station_code         name  ... แขวง/ตำบล รหัสไปรษณีย์ หมายเหตุ
# 0       NaN           NaN          NaN  ...       NaN          NaN      NaN
# 1       NaN           NaN          NaN  ...   ห้วยยอด      92130.0      NaN
# 2       NaN           NaN          NaN  ...       NaN          NaN      NaN
# 3       NaN           NaN          NaN  ...       NaN          NaN      NaN
# 4     102.0        1164.0      เด่นชัย  ...   เด่นชัย      54110.0      NaN
# ...     ...           ...          ...  ...       ...          ...      ...
# 1106    NaN           NaN          NaN  ...   ทุ่งทอง      62190.0      NaN
# 1107    NaN           NaN          NaN  ...   ทุ่งทอง      71110.0      NaN
# 1108  297.0        2305.0  ตลาดหนองคาย  ...       NaN          NaN      NaN
# 1109    NaN           NaN          NaN  ...       NaN          NaN      NaN
# 1110    NaN           NaN          NaN  ...       NaN          NaN      NaN
#
# [1111 rows x 48 columns]

# %%
merged_4_tables = merged_4_tables_new.merge(data_location,how='left',left_on='NAMET',right_on='จังหวัด')  ##ทำการเชื่อมตารางอีกรอบ โดยใช้คีย์ NAMET กับ จังหวัด เนื่องจาก NAMET ตรงกับชื่อจังหวัด แต่ตอนที่เชื่อมตารางก่อนหน้า ถูกเชื่อมด้วย แขวง/ตำบล

# %%
merged_4_tables
# Out:
#           id  station_code         name  ... แขวง/ตำบล_y รหัสไปรษณีย์_y หมายเหตุ_y
# 0        NaN           NaN          NaN  ...         NaN            NaN        NaN
# 1        NaN           NaN          NaN  ...         NaN            NaN        NaN
# 2        NaN           NaN          NaN  ...         NaN            NaN        NaN
# 3        NaN           NaN          NaN  ...         NaN            NaN        NaN
# 4      102.0        1164.0      เด่นชัย  ...         NaN            NaN        NaN
# ...      ...           ...          ...  ...         ...            ...        ...
# 14054    NaN           NaN          NaN  ...         NaN            NaN        NaN
# 14055    NaN           NaN          NaN  ...         NaN            NaN        NaN
# 14056  297.0        2305.0  ตลาดหนองคาย  ...         NaN            NaN        NaN
# 14057    NaN           NaN          NaN  ...         NaN            NaN        NaN
# ...

# %%
merged_4_tables.isnull().sum()  ## เช็ค missing
# Out:
# id                  2579
# station_code        2579
# name                2579
# en_name             2579
# th_short            2579
# en_short            2579
# chname              2579
# controldivision     2579
# exact_km            2579
# exact_distance      2579
# km                  2579
# class               2579
# lat                 2579
# long                2579
# active              2579
# giveway             2579
# dual_track          2579
# comment            14059
# Zone                2579
# goback              2579
# Num                 2579
# IdTrain             2579
# NameFee             2579
# StStart             2579
# NameSt              2579
# StFinal             2579
# NameSt_L            2579
# NameStEng           2579
# NameStEng_L         2579
# Service             2579
# OBJECTID               0
# NAMET                  0
# NAMEE                  0
# ProvName               0
# AmpName                0
# TamName                0
# X                      0
# ...

# %%
merged_4_tables.drop(['ProvName', 'AmpName','TamName'], axis='columns', inplace=True) ## ทำการตัด Column ที่ไม่ได้ใช้ออก ได้แก่ 'ProvName', 'AmpName' และ 'TamName'

# %%
merged_4_tables ## เรียกดูตารางที่ถูกแก้ล่าสุด
# Out:
#           id  station_code         name  ... แขวง/ตำบล_y รหัสไปรษณีย์_y หมายเหตุ_y
# 0        NaN           NaN          NaN  ...         NaN            NaN        NaN
# 1        NaN           NaN          NaN  ...         NaN            NaN        NaN
# 2        NaN           NaN          NaN  ...         NaN            NaN        NaN
# 3        NaN           NaN          NaN  ...         NaN            NaN        NaN
# 4      102.0        1164.0      เด่นชัย  ...         NaN            NaN        NaN
# ...      ...           ...          ...  ...         ...            ...        ...
# 14054    NaN           NaN          NaN  ...         NaN            NaN        NaN
# 14055    NaN           NaN          NaN  ...         NaN            NaN        NaN
# 14056  297.0        2305.0  ตลาดหนองคาย  ...         NaN            NaN        NaN
# 14057    NaN           NaN          NaN  ...         NaN            NaN        NaN
# ...

# %%
t = merged_4_tables.groupby(['class','NAMET']) ## ทำการแบ่งกลุ่ม class และ รวม NAMET เข้าไปในแต่ละ class 
t.first()
# Out:
#                            id  ...                                         หมายเหตุ_y
# class NAMET                    ...
# 1.0   ขอนแก่น           232.0  ...  ยกเว้น ต.น้ำพอง หมู่ที่ 2-8, 13, 15, 16  ใช้รห...
#       ชุมทางฉะเชิงเทรา  315.0  ...                                               None
#       ชุมทางทุ่งสง      558.0  ...                                               None
#       ชุมทางบัวใหญ่     220.0  ...                                               None
#       ชุมทางบางซื่อ       5.0  ...                                               None
#       ชุมทางบ้านภาชี     26.0  ...                                               None
#       ชุมทางหาดใหญ่     612.0  ...                                               None
#       ชุมทางแก่งคอย     145.0  ...                                               None
#       ชุมพร             501.0  ...  ยกเว้น ต.ท่ายาง เฉพาะหมู่ที่ 1,9-10 ใช้รหัสไปร...
# ...
